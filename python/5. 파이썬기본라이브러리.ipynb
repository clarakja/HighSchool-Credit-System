# %%
import math
import numpy as np
array = np.array([1, 2, 3])
print(math.sqrt(16))  # 4.0
print(math.factorial(5))  # 120
print(math.pow(2, 3))  # 8.0
print(math.log(100, 10))  # 2.0
print(math.sin(math.pi / 2))  # 1.0
# Out:
# 4.0
# 120
# 8.0
# 2.0
# 1.0

# %%
import random

print(random.random())  # 0~1 사이 난수
print(random.randint(1, 10))  # 1~10 사이 정수
print(random.choice(["사과", "바나나", "포도"]))  # 리스트에서 랜덤 선택
lotto = list(range(1, 46))
random.shuffle(lotto)  # 리스트 요소 섞기
print(lotto[:6])  # 6개 번호 선택
# Out:
# 0.4525851247517244
# 8
# 사과
# [40, 38, 23, 35, 9, 33]

# %%
from datetime import datetime, timedelta

now = datetime.now()
print("현재 시간:", now)

formatted_date = now.strftime("%Y-%m-%d %H:%M:%S")
print("포맷 변경:", formatted_date)

future_date = now + timedelta(days=7)
print("7일 후:", future_date)
# Out:
# 현재 시간: 2025-01-30 01:38:42.841892
# 포맷 변경: 2025-01-30 01:38:42
# 7일 후: 2025-02-06 01:38:42.841892

# %%
import time

print("3초 대기 중...")
time.sleep(3)  # 3초 대기
print("실행 완료!")
# Out:
# 3초 대기 중...
# 실행 완료!

# %%
import os

print("현재 디렉토리:", os.getcwd())
os.makedirs("새폴더", exist_ok=True)
print("폴더 생성 완료!")
# Out:
# 현재 디렉토리: /content
# 폴더 생성 완료!
