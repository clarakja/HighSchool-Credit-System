# %%
from nltk.corpus import stopwords
import nltk
# NLTK의 불용어 다운로드
nltk.download('stopwords')
# 영어 불용어 가져오기
stop_words = set(stopwords.words('english'))
# 텍스트 데이터
text = "This is an example sentence showing the removal of stop words."
# 불용어 제거
filtered_words = [word for word in text.split() if word.lower() not in stop_words]
print(filtered_words)
# 출력: ['example', 'sentence', 'showing', 'removal', 'stop', 'words']
# Out:
# ['example', 'sentence', 'showing', 'removal', 'stop', 'words.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install konlpy
from konlpy.tag import Okt
# 사용자 정의 한국어 불용어 리스트
stop_words = ["은", "는", "이", "가", "을", "를", "에", "의", "로", "와", "과"]
# 텍스트 데이터
text = "이 영화는 정말 재미있었고 감동적이었습니다."
# 형태소 분석
okt = Okt()
tokens = okt.morphs(text)
# 불용어 제거
filtered_words = [word for word in tokens if word not in stop_words]
print(filtered_words)
# 출력: ['영화', '정말', '재미있', '감동적이었습니다']
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 72.7 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 31.5 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0
# ['영화', '정말', '재미있었고', '감동', '적', '이었습니다', '.']
